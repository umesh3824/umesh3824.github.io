# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./Datasets//Google_Stock_Price_Train.csv')
testData = pd.read_csv('./Datasets//Google_Stock_Price_Test.csv')

# %%
print(data.shape)
data.head()
# Out:
# (1258, 6)
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
print(testData.shape)
testData.head()
# Out:
# (20, 6)
#        Date    Open    High     Low   Close     Volume
# 0  1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1  1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2  1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3  1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4  1/9/2017  806.40  809.97  802.83  806.65  1,272,400

# %%
data.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
testData.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
def FloatConversion(x):
    x = str(x)
    x = x.replace(',', '').replace("'", '')
    return float(x)


data = data[['Date', 'Close']]
testData = testData[['Date', 'Close']]


data['Close'] = data['Close'].apply(FloatConversion)
testData['Close'] = testData['Close'].apply(FloatConversion)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Close   1258 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.8+ KB

# %%
testData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 448.0+ bytes

# %%
data.head()
# Out:
#        Date   Close
# 0  1/3/2012  663.59
# 1  1/4/2012  666.45
# 2  1/5/2012  657.21
# 3  1/6/2012  648.24
# 4  1/9/2012  620.76

# %%
testData.head()
# Out:
#        Date   Close
# 0  1/3/2017  786.14
# 1  1/4/2017  786.90
# 2  1/5/2017  794.02
# 3  1/6/2017  806.15
# 4  1/9/2017  806.65

# %%
plt.figure(figsize=(15, 5))
plt.plot(data['Close'])
plt.title('Google Stock Price (Training Set)')
plt.show()

plt.figure(figsize=(15, 5))
plt.plot(testData['Close'])
plt.title('Google Stock Price (Test Set)')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))

data['Close'] = sc.fit_transform(data['Close'].values.reshape(-1, 1))
testData['Close'] = sc.transform(testData['Close'].values.reshape(-1, 1))

# %%
data.head()
# Out:
#        Date     Close
# 0  1/3/2012  0.237573
# 1  1/4/2012  0.241514
# 2  1/5/2012  0.228781
# 3  1/6/2012  0.216419
# 4  1/9/2012  0.178548

# %%
testData.head()
# Out:
#        Date     Close
# 0  1/3/2017  0.406461
# 1  1/4/2017  0.407508
# 2  1/5/2017  0.417320
# 3  1/6/2017  0.434037
# 4  1/9/2017  0.434726

# %%
plt.figure(figsize=(15, 5))
plt.plot(data['Close'])
plt.title('Google Stock Price (Training Set)')
plt.show()

plt.figure(figsize=(15, 5))
plt.plot(testData['Close'])
plt.title('Google Stock Price (Test Set)')
plt.show()

# %%
X_train = []
y_train = []
timesteps = 50
CloseData = list(data['Close'])
for i in range(timesteps, len(CloseData)):
    X_train.append(CloseData[i-timesteps:i])
    y_train.append(CloseData[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (1208, 50) (1208,)

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout

model = Sequential()
model.add(SimpleRNN(units=50, activation='tanh', return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50, activation='tanh'))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50, 50)            2600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 50, 50)            5050
#
#  dropout_1 (Dropout)         (None, 50, 50)            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 50, 50)            5050
#
#  dropout_2 (Dropout)         (None, 50, 50)            0
#
#  simple_rnn_3 (SimpleRNN)    (None, 50)                5050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 17,801
# Trainable params: 17,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 4s 29ms/step - loss: 0.3709
# Epoch 2/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.2622
# Epoch 3/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.1530
# Epoch 4/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.1161
# Epoch 5/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0903
# Epoch 6/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0710
# Epoch 7/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0597
# Epoch 8/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0481
# Epoch 9/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0403
# Epoch 10/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0355
# Epoch 11/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0318
# Epoch 12/100
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0292
# Epoch 13/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0285
# Epoch 14/100
# 38/38 [==============================] - 1s 39ms/step - loss: 0.0229
# Epoch 15/100
# 38/38 [==============================] - 1s 33ms/step - loss: 0.0194
# Epoch 16/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0196
# Epoch 17/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0166
# Epoch 18/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0145
# Epoch 19/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0159
# Epoch 20/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0144
# Epoch 21/100
# 38/38 [==============================] - 1s 33ms/step - loss: 0.0135
# Epoch 22/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0115
# Epoch 23/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0123
# Epoch 24/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0102
# Epoch 25/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0099
# Epoch 26/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0090
# Epoch 27/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0089
# Epoch 28/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0083
# Epoch 29/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0073
# Epoch 30/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0076
# Epoch 31/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0077
# Epoch 32/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0068
# Epoch 33/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0068
# Epoch 34/100
# 38/38 [==============================] - 1s 37ms/step - loss: 0.0066
# Epoch 35/100
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0066
# Epoch 36/100
# 38/38 [==============================] - 1s 37ms/step - loss: 0.0059
# Epoch 37/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0062
# Epoch 38/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0063
# Epoch 39/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0062
# Epoch 40/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0053
# Epoch 41/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0050
# Epoch 42/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0050
# Epoch 43/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0052
# Epoch 44/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0048
# Epoch 45/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0048
# Epoch 46/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0043
# Epoch 47/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0047
# Epoch 48/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0052
# Epoch 49/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0044
# Epoch 50/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0038
# Epoch 51/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0047
# Epoch 52/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0043
# Epoch 53/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0043
# Epoch 54/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0033
# Epoch 55/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0031
# Epoch 56/100
# 38/38 [==============================] - 1s 33ms/step - loss: 0.0036
# Epoch 57/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0037
# Epoch 58/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0033
# Epoch 59/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0033
# Epoch 60/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0044
# Epoch 61/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0034
# Epoch 62/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0033
# Epoch 63/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0031
# Epoch 64/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0031
# Epoch 65/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0030
# Epoch 66/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0031
# Epoch 67/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0031
# Epoch 68/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0031
# Epoch 69/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0029
# Epoch 70/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0026
# Epoch 71/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0030
# Epoch 72/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0028
# Epoch 73/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0028
# Epoch 74/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0028
# Epoch 75/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0025
# Epoch 76/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0025
# Epoch 77/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0025
# Epoch 78/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0032
# Epoch 79/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0029
# Epoch 80/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0026
# Epoch 81/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0027
# Epoch 82/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0027
# Epoch 83/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0028
# Epoch 84/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0025
# Epoch 85/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0026
# Epoch 86/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0025
# Epoch 87/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0024
# Epoch 88/100
# 38/38 [==============================] - 1s 31ms/step - loss: 0.0022
# Epoch 89/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0021
# Epoch 90/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0023
# Epoch 91/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0025
# Epoch 92/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0025
# Epoch 93/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0021
# Epoch 94/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0020
# Epoch 95/100
# 38/38 [==============================] - 1s 33ms/step - loss: 0.0022
# Epoch 96/100
# 38/38 [==============================] - 1s 33ms/step - loss: 0.0020
# Epoch 97/100
# 38/38 [==============================] - 1s 33ms/step - loss: 0.0027
# Epoch 98/100
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0026
# Epoch 99/100
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0022
# Epoch 100/100
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0021

# %%
ypred = model.predict(X_train)
ypred = sc.inverse_transform(ypred)

y_train = sc.inverse_transform(y_train.reshape(-1, 1))


plt.figure(figsize=(15, 5))
plt.plot(ypred, color='red', label='Predicted Google Stock Price')
plt.plot(y_train, color='blue', label='Actual Google Stock Price')
plt.title('Google Stock Price Prediction (Training Set)')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
# Out:
# 38/38 [==============================] - 1s 11ms/step

# %%
XTest = []
CloseData = list(testData['Close'])
timeSteps = 50

trainLast = list(data['Close'])[-timeSteps:]

CloseData = trainLast + CloseData

for i in range(timeSteps, len(CloseData)):
    XTest.append(CloseData[i-timeSteps:i])

XTest = np.array(XTest)
print(XTest.shape)
# Out:
# (20, 50)

# %%
ypred = model.predict(XTest)
ypred = sc.inverse_transform(ypred)

Orignal = sc.inverse_transform(testData['Close'].values.reshape(-1, 1))

plt.figure(figsize=(15, 5))
plt.plot(ypred, color='red', label='Predicted Google Stock Price')
plt.plot(Orignal, color='blue', label='Actual Google Stock Price')
plt.title('Google Stock Price Prediction (test set))')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 32ms/step
