# %% [markdown]
# # DSBDA Assignment-10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(11.7, 8.27)})

# %%
df = pd.read_csv('E:\DSDBA\iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['sepal_length'].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3ea26f590f61> in <module>
# ----> 1 df['sepal_length'].dtype()
#
# TypeError: 'numpy.dtype' object is not callable

# %%
df.shape
# Out:
# (150, 5)

# %%
df.valuecount(df['sepal_length'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-2ac722226631> in <module>
# ----> 1 df.valuecount(df['sepal_length'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'valuecount'

# %%
sns.countplot(x='sepal_length', data=df)
plt.title('Species Count')
# Out:
# Text(0.5, 1.0, 'Species Count')

# %%
df['sepal_length'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Create Histogram for each feature in the dataset to illustrate feature distribution

# %%
sns.histplot(x='sepal_length', data=df, kde=True)

# %%
sns.histplot(x='petal_length', data=df, kde=True)

# %%
sns.histplot(x='sepal_width', data=df, kde=True)

# %%
sns.histplot(x='petal_width', data=df, kde=True)

# %%
sns.histplot(x='species', data=df, kde=True)

# %% [markdown]
# ## Create a box plot for all above features in dataset

# %%
sns.boxplot(x='sepal_length', data=df)

# %%
sns.boxplot(x='petal_length', data=df)

# %%
sns.boxplot(x='sepal_width', data=df)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.boxplot(x='petal_width', data=df)

# %%
plt.scatter(x='sepal_length', y='petal_length', data=df)

# %%
sns.displot(x='petal_length', data=df, kind='hist', kde=True)
