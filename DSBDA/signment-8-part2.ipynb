# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('E:\\DSDBA\\train.csv')
#what is the maximum fare?
sns.barplot(x = 'PassengerId', y='Fare', data=df)

# %%
sns.catplot(x = 'PassengerId', y='Fare', data=df)
